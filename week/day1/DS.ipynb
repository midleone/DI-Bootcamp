# %% [markdown]
# <a href="https://colab.research.google.com/github/midleone/DI-Bootcamp/blob/main/week/day1/DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

temperature_data = np.random.uniform(low=-5, high=35, size=(10, 12))

cities = ['City1', 'City2', 'City3', 'City4', 'City5', 'City6', 'City7', 'City8', 'City9', 'City10']
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

temperature_df = pd.DataFrame(temperature_data, index=cities, columns=months)

print(temperature_df)
# Out:
#               Jan        Feb        Mar        Apr        May        Jun  \
# City1    9.981605  33.028572  24.279758  18.946339   1.240746   1.239781
# City2   28.297706   3.493564   2.272999   2.336180   7.169690  15.990257
# City3   13.242799  26.407038   2.986951  15.569378  18.696583  -3.141983
# City4    7.184551  -1.093115  22.369321  12.606100  -0.118471  14.807076
# City5   16.868411   2.394178  33.783385  26.005313  32.579958  30.793094
# City6   10.547092   5.853961  28.149500   9.270133   6.237380  16.707843
# City7   -4.779115  27.618457  23.274294  24.160287  25.850814  -2.038214
# City8    7.439293   8.007333  24.184247  20.502299  30.488510  13.888597
# City9   15.909313  12.101641  -3.983235  -0.684343  -3.742833  20.456416
# City10   4.151927  -1.920804   6.590058   1.448851  32.187906  27.324815
#
#               Jul        Aug        Sep        Oct        Nov        Dec
# City1   -2.676656  29.647046  19.044600  23.322903  -4.176620  33.796394
# ...

# %%
annual_avg_temperature = temperature_df.mean(axis=1)

hottest_city = annual_avg_temperature.idxmax()
coldest_city = annual_avg_temperature.idxmin()

print("Annual Average Temperature:")
print(annual_avg_temperature)

print("\nCity with the Highest Average Temperature:", hottest_city)
print("City with the Lowest Average Temperature:", coldest_city)
# Out:
# Annual Average Temperature:
# City1     15.639539
# City2      9.573458
# City3     15.533515
# City4     11.135589
# City5     16.618052
# City6     13.815557
# City7     13.191186
# City8     17.608070
# City9     11.323811
# City10    16.405255
# dtype: float64
#
# City with the Highest Average Temperature: City8
# City with the Lowest Average Temperature: City2

# %%
for city in temperature_df.index:
    if city == hottest_city:
        plt.plot(months, temperature_df.loc[city], label=city, linewidth=2, linestyle='--', color='red')
    elif city == coldest_city:
        plt.plot(months, temperature_df.loc[city], label=city, linewidth=2, linestyle='-.', color='blue')
    else:
        plt.plot(months, temperature_df.loc[city], label=city, linewidth=1, linestyle='-', color='gray')

plt.title('Monthly Temperature Trends for Each City')
plt.xlabel('Month')
plt.ylabel('Temperature (°C)')
plt.legend()

plt.show()
